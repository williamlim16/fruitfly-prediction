# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import optuna

from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset
from torch.utils.tensorboard import SummaryWriter

# %%
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")

# %% [markdown]
# # With PCA

# %%
df = pd.read_csv("preprocessed.csv")
X = df.iloc[:, :-1]
y = df.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
X_train_tensor = torch.tensor(X_train.values, dtype=torch.float32).to(device)
y_train_tensor = torch.tensor(y_train.values, dtype=torch.long).to(device)
X_test_tensor = torch.tensor(X_test.values, dtype=torch.float32).to(device)
y_test_tensor = torch.tensor(y_test.values, dtype=torch.long).to(device)

# %%
class SimpleNN(nn.Module):
    def __init__(self, input_size, hidden_size1, hidden_size2, output_size, activation_function):
        super(SimpleNN, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)
        self.fc3 = nn.Linear(hidden_size2, 20)
        self.fc4 = nn.Linear(20, output_size)
        activation_functions = {
            'relu': F.relu,
            'tanh': torch.tanh,
            'sigmoid': torch.sigmoid
        }
        self.activate = activation_functions[activation_function]

    def forward(self, x):
        x = self.activate(self.fc1(x))
        x = self.activate(self.fc2(x))
        x = self.activate(self.fc3(x))
        x = self.fc4(x)
        return x

# %%
def objective(trial):
    hidden_size1 = trial.suggest_int('hidden_size1', 64, 256)
    hidden_size2 = trial.suggest_int('hidden_size2', 32, 128)
    lr = trial.suggest_float('lr', 1e-5, 1e-1, log=True)
    batch_size = trial.suggest_int('batch_size', 16, 128)
    activation_function = trial.suggest_categorical(
        'activation_function', ['relu', 'tanh', 'sigmoid'])

    model = SimpleNN(input_size=X_train.shape[1], hidden_size1=hidden_size1,
                     hidden_size2=hidden_size2, output_size=len(
                         np.unique(y_train)),
                     activation_function=activation_function).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)
    writer = SummaryWriter(
        f'runs/op_{hidden_size1}_{hidden_size2}_{lr}_{batch_size}')

    train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
    train_loader = DataLoader(
        train_dataset, batch_size=batch_size, shuffle=True)

    num_epochs = 100
    for epoch in range(num_epochs):
        model.train()
        for i, (inputs, labels) in enumerate(train_loader):
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            writer.add_scalar('training_loss', loss.item(),
                              epoch * len(train_loader) + i)

        model.eval()
        with torch.no_grad():
            predicted_outputs = model(X_test_tensor)
            _, predicted_classes = torch.max(predicted_outputs, 1)
            accuracy = (predicted_classes == y_test_tensor).sum(
            ).item() / y_test_tensor.size(0)
            writer.add_scalar('test_accuracy', accuracy, epoch)

        model.train()

    writer.close()
    return accuracy


study = optuna.create_study(
    study_name="activation_function_100",
    storage='sqlite:///log.db',
    direction='maximize')
study.optimize(objective, n_trials=100)

print("Best trial:")
trial = study.best_trial

print(f"  Value: {trial.value}")
print("  Params: ")
for key, value in trial.params.items():
    print(f"    {key}: {value}")
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File ~/anaconda3/envs/machinelearning/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#
# File ~/anaconda3/envs/machinelearning/lib/python3.10/site-packages/sqlalchemy/engine/default.py:922, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     921 def do_execute(self, cursor, statement, parameters, context=None):
# --> 922     cursor.execute(statement, parameters)
#
# IntegrityError: UNIQUE constraint failed: studies.study_name
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# File ~/anaconda3/envs/machinelearning/lib/python3.10/site-packages/optuna/storages/_rdb/storage.py:264, in RDBStorage.create_new_study(self, directions, study_name)
#     263 try:
# --> 264     with _create_scoped_session(self.scoped_session) as session:
#     265         if study_name is None:
#
# File ~/anaconda3/envs/machinelearning/lib/python3.10/contextlib.py:142, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     141 try:
# --> 142     next(self.gen)
#     143 except StopIteration:
#
# File ~/anaconda3/envs/machinelearning/lib/python3.10/site-packages/optuna/storages/_rdb/storage.py:73, in _create_scoped_session(scoped_session, ignore_integrity_error)
#      72     yield session
# ---> 73     session.commit()
#      74 except sqlalchemy_exc.IntegrityError as e:
#
# File ~/anaconda3/envs/machinelearning/lib/python3.10/site-packages/sqlalchemy/orm/session.py:1969, in Session.commit(self)
#    1967     trans = self._autobegin_t()
# -> 1969 trans.commit(_to_root=True)
#
# File <string>:2, in commit(self, _to_root)
#
# File ~/anaconda3/envs/machinelearning/lib/python3.10/site-packages/sqlalchemy/orm/state_changes.py:139, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     138 try:
# --> 139     ret_value = fn(self, *arg, **kw)
#     140 except:
#
# File ~/anaconda3/envs/machinelearning/lib/python3.10/site-packages/sqlalchemy/orm/session.py:1256, in SessionTransaction.commit(self, _to_root)
#    1255     with self._expect_state(SessionTransactionState.PREPARED):
# -> 1256         self._prepare_impl()
#    1258 if self._parent is None or self.nested:
#
# File <string>:2, in _prepare_impl(self)
#
# File ~/anaconda3/envs/machinelearning/lib/python3.10/site-packages/sqlalchemy/orm/state_changes.py:139, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     138 try:
# --> 139     ret_value = fn(self, *arg, **kw)
#     140 except:
#
# File ~/anaconda3/envs/machinelearning/lib/python3.10/site-packages/sqlalchemy/orm/session.py:1231, in SessionTransaction._prepare_impl(self)
#    1230         break
# -> 1231     self.session.flush()
#    1232 else:
#
# File ~/anaconda3/envs/machinelearning/lib/python3.10/site-packages/sqlalchemy/orm/session.py:4312, in Session.flush(self, objects)
#    4311     self._flushing = True
# -> 4312     self._flush(objects)
#    4313 finally:
#
# File ~/anaconda3/envs/machinelearning/lib/python3.10/site-packages/sqlalchemy/orm/session.py:4447, in Session._flush(self, objects)
#    4446 except:
# -> 4447     with util.safe_reraise():
#    4448         transaction.rollback(_capture_exception=True)
#
# File ~/anaconda3/envs/machinelearning/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File ~/anaconda3/envs/machinelearning/lib/python3.10/site-packages/sqlalchemy/orm/session.py:4408, in Session._flush(self, objects)
#    4407 try:
# -> 4408     flush_context.execute()
#    4409 finally:
#
# File ~/anaconda3/envs/machinelearning/lib/python3.10/site-packages/sqlalchemy/orm/unitofwork.py:466, in UOWTransaction.execute(self)
#     465 for rec in topological.sort(self.dependencies, postsort_actions):
# --> 466     rec.execute(self)
#
# File ~/anaconda3/envs/machinelearning/lib/python3.10/site-packages/sqlalchemy/orm/unitofwork.py:642, in SaveUpdateAll.execute(self, uow)
#     640 @util.preload_module("sqlalchemy.orm.persistence")
#     641 def execute(self, uow):
# --> 642     util.preloaded.orm_persistence.save_obj(
#     643         self.mapper,
#     644         uow.states_for_mapper_hierarchy(self.mapper, False, False),
#     645         uow,
#     646     )
#
# File ~/anaconda3/envs/machinelearning/lib/python3.10/site-packages/sqlalchemy/orm/persistence.py:93, in save_obj(base_mapper, states, uowtransaction, single)
#      85     _emit_update_statements(
#      86         base_mapper,
#      87         uowtransaction,
#    (...)
#      90         update,
#      91     )
# ---> 93     _emit_insert_statements(
#      94         base_mapper,
#      95         uowtransaction,
#      96         mapper,
#      97         table,
#      98         insert,
#      99     )
#     101 _finalize_insert_update_commands(
#     102     base_mapper,
#     103     uowtransaction,
#    (...)
#     119     ),
#     120 )
#
# File ~/anaconda3/envs/machinelearning/lib/python3.10/site-packages/sqlalchemy/orm/persistence.py:1227, in _emit_insert_statements(base_mapper, uowtransaction, mapper, table, insert, bookkeeping, use_orm_insert_stmt, execution_options)
#    1226 else:
# -> 1227     result = connection.execute(
#    1228         statement,
#    1229         params,
#    1230         execution_options=execution_options,
#    1231     )
#    1233 primary_key = result.inserted_primary_key
#
# File ~/anaconda3/envs/machinelearning/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1416, in Connection.execute(self, statement, parameters, execution_options)
#    1415 else:
# -> 1416     return meth(
#    1417         self,
#    1418         distilled_parameters,
#    1419         execution_options or NO_OPTIONS,
#    1420     )
#
# File ~/anaconda3/envs/machinelearning/lib/python3.10/site-packages/sqlalchemy/sql/elements.py:517, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     516         assert isinstance(self, Executable)
# --> 517     return connection._execute_clauseelement(
#     518         self, distilled_params, execution_options
#     519     )
#     520 else:
#
# File ~/anaconda3/envs/machinelearning/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1639, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1631 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1632     dialect=dialect,
#    1633     compiled_cache=compiled_cache,
#    (...)
#    1637     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1638 )
# -> 1639 ret = self._execute_context(
#    1640     dialect,
#    1641     dialect.execution_ctx_cls._init_compiled,
#    1642     compiled_sql,
#    1643     distilled_parameters,
#    1644     execution_options,
#    1645     compiled_sql,
#    1646     distilled_parameters,
#    1647     elem,
#    1648     extracted_params,
#    1649     cache_hit=cache_hit,
#    1650 )
#    1651 if has_events:
#
# File ~/anaconda3/envs/machinelearning/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1848, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1847 else:
# -> 1848     return self._exec_single_context(
#    1849         dialect, context, statement, parameters
#    1850     )
#
# File ~/anaconda3/envs/machinelearning/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1988, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1987 except BaseException as e:
# -> 1988     self._handle_dbapi_exception(
#    1989         e, str_statement, effective_parameters, cursor, context
#    1990     )
#    1992 return result
#
# File ~/anaconda3/envs/machinelearning/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2344, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2343     assert sqlalchemy_exception is not None
# -> 2344     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2345 else:
#
# File ~/anaconda3/envs/machinelearning/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#
# File ~/anaconda3/envs/machinelearning/lib/python3.10/site-packages/sqlalchemy/engine/default.py:922, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     921 def do_execute(self, cursor, statement, parameters, context=None):
# --> 922     cursor.execute(statement, parameters)
#
# IntegrityError: (sqlite3.IntegrityError) UNIQUE constraint failed: studies.study_name
# [SQL: INSERT INTO studies (study_name) VALUES (?)]
# [parameters: ('activation_function_100',)]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
#
# During handling of the above exception, another exception occurred:
#
# DuplicatedStudyError                      Traceback (most recent call last)
# Cell In[50], line 53
#      49     writer.close()
#      50     return accuracy
# ---> 53 study = optuna.create_study(
#      54     study_name="activation_function_100",
#      55     storage='sqlite:///log.db',
#      56     direction='maximize')
#      57 study.optimize(objective, n_trials=100)
#      59 print("Best trial:")
#
# File ~/anaconda3/envs/machinelearning/lib/python3.10/site-packages/optuna/_convert_positional_args.py:83, in convert_positional_args.<locals>.converter_decorator.<locals>.converter_wrapper(*args, **kwargs)
#      77     raise TypeError(
#      78         f"{func.__name__}() got multiple values for arguments {duplicated_kwds}."
#      79     )
#      81 kwargs.update(inferred_kwargs)
# ---> 83 return func(**kwargs)
#
# File ~/anaconda3/envs/machinelearning/lib/python3.10/site-packages/optuna/study/study.py:1251, in create_study(storage, sampler, pruner, study_name, direction, load_if_exists, directions)
#    1249 storage = storages.get_storage(storage)
#    1250 try:
# -> 1251     study_id = storage.create_new_study(direction_objects, study_name)
#    1252 except exceptions.DuplicatedStudyError:
#    1253     if load_if_exists:
#
# File ~/anaconda3/envs/machinelearning/lib/python3.10/site-packages/optuna/storages/_cached_storage.py:82, in _CachedStorage.create_new_study(self, directions, study_name)
#      79 def create_new_study(
#      80     self, directions: Sequence[StudyDirection], study_name: Optional[str] = None
#      81 ) -> int:
# ---> 82     study_id = self._backend.create_new_study(directions=directions, study_name=study_name)
#      83     with self._lock:
#      84         study = _StudyInfo()
#
# File ~/anaconda3/envs/machinelearning/lib/python3.10/site-packages/optuna/storages/_rdb/storage.py:276, in RDBStorage.create_new_study(self, directions, study_name)
#     273         session.add(models.StudyModel(study_name=study_name, directions=direction_models))
#     275 except sqlalchemy_exc.IntegrityError:
# --> 276     raise optuna.exceptions.DuplicatedStudyError(
#     277         "Another study with name '{}' already exists. "
#     278         "Please specify a different name, or reuse the existing one "
#     279         "by setting `load_if_exists` (for Python API) or "
#     280         "`--skip-if-exists` flag (for CLI).".format(study_name)
#     281     )
#     283 _logger.info("A new study created in RDB with name: {}".format(study_name))
#     285 return self.get_study_id_from_name(study_name)
#
# DuplicatedStudyError: Another study with name 'activation_function_100' already exists. Please specify a different name, or reuse the existing one by setting `load_if_exists` (for Python API) or `--skip-if-exists` flag (for CLI).

# %% [markdown]
# # Without PCA

# %%
df = pd.read_csv("data_without_pca.csv")
X = df.iloc[:, 1:]
y = df.iloc[:, 0]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
X_train_tensor = torch.tensor(X_train.values, dtype=torch.float32).to(device)
y_train_tensor = torch.tensor(y_train.values, dtype=torch.long).to(device)
X_test_tensor = torch.tensor(X_test.values, dtype=torch.float32).to(device)
y_test_tensor = torch.tensor(y_test.values, dtype=torch.long).to(device)

# %%
class SimpleNN(nn.Module):
    def __init__(self, input_size, hidden_size1, hidden_size2, output_size, activation_function):
        super(SimpleNN, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)
        self.fc3 = nn.Linear(hidden_size2, 20)
        self.fc4 = nn.Linear(20, output_size)
        activation_functions = {
            'relu': F.relu,
            'tanh': torch.tanh,
            'sigmoid': torch.sigmoid
        }
        self.activate = activation_functions[activation_function]

    def forward(self, x):
        x = self.activate(self.fc1(x))
        x = self.activate(self.fc2(x))
        x = self.activate(self.fc3(x))
        x = self.fc4(x)
        return x

# %%
def objective(trial):
    hidden_size1 = trial.suggest_int('hidden_size1', 64, 256)
    hidden_size2 = trial.suggest_int('hidden_size2', 32, 128)
    lr = trial.suggest_float('lr', 1e-5, 1e-1, log=True)
    batch_size = trial.suggest_int('batch_size', 16, 128)
    activation_function = trial.suggest_categorical(
        'activation_function', ['relu', 'tanh', 'sigmoid'])

    model = SimpleNN(input_size=X_train.shape[1], hidden_size1=hidden_size1,
                     hidden_size2=hidden_size2, output_size=len(
                         np.unique(y_train)),
                     activation_function=activation_function).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)
    writer = SummaryWriter(
        f'runs/op_{hidden_size1}_{hidden_size2}_{lr}_{batch_size}')

    train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
    train_loader = DataLoader(
        train_dataset, batch_size=batch_size, shuffle=True)

    num_epochs = 100
    for epoch in range(num_epochs):
        model.train()
        for i, (inputs, labels) in enumerate(train_loader):
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            writer.add_scalar('training_loss', loss.item(),
                              epoch * len(train_loader) + i)

        model.eval()
        with torch.no_grad():
            predicted_outputs = model(X_test_tensor)
            _, predicted_classes = torch.max(predicted_outputs, 1)
            accuracy = (predicted_classes == y_test_tensor).sum(
            ).item() / y_test_tensor.size(0)
            writer.add_scalar('test_accuracy', accuracy, epoch)

        model.train()

    writer.close()
    return accuracy


study = optuna.create_study(
    study_name="activation_function_100_w_pca",
    storage='sqlite:///log.db',
    direction='maximize')
study.optimize(objective, n_trials=100)

print("Best trial:")
trial = study.best_trial

print(f"  Value: {trial.value}")
print("  Params: ")
for key, value in trial.params.items():
    print(f"    {key}: {value}")
# Out:
# [I 2024-05-20 17:17:34,868] A new study created in RDB with name: activation_function_100_w_pca
# [I 2024-05-20 17:18:08,746] Trial 0 finished with value: 0.7020785219399538 and parameters: {'hidden_size1': 77, 'hidden_size2': 51, 'lr': 0.009684488959166704, 'batch_size': 22, 'activation_function': 'tanh'}. Best is trial 0 with value: 0.7020785219399538.
# [I 2024-05-20 17:18:25,380] Trial 1 finished with value: 0.7321016166281755 and parameters: {'hidden_size1': 195, 'hidden_size2': 79, 'lr': 0.0007364011407376165, 'batch_size': 76, 'activation_function': 'relu'}. Best is trial 1 with value: 0.7321016166281755.
# [I 2024-05-20 17:18:38,478] Trial 2 finished with value: 0.6327944572748267 and parameters: {'hidden_size1': 124, 'hidden_size2': 53, 'lr': 0.00011989221681046469, 'batch_size': 91, 'activation_function': 'relu'}. Best is trial 1 with value: 0.7321016166281755.
# [I 2024-05-20 17:18:57,527] Trial 3 finished with value: 0.6535796766743649 and parameters: {'hidden_size1': 99, 'hidden_size2': 116, 'lr': 4.244700771126413e-05, 'batch_size': 51, 'activation_function': 'tanh'}. Best is trial 1 with value: 0.7321016166281755.
# [I 2024-05-20 17:19:20,383] Trial 4 finished with value: 0.7806004618937644 and parameters: {'hidden_size1': 223, 'hidden_size2': 123, 'lr': 0.009243325883276787, 'batch_size': 40, 'activation_function': 'relu'}. Best is trial 4 with value: 0.7806004618937644.
# [I 2024-05-20 17:19:31,760] Trial 5 finished with value: 0.6720554272517321 and parameters: {'hidden_size1': 86, 'hidden_size2': 89, 'lr': 0.003274247899642107, 'batch_size': 127, 'activation_function': 'sigmoid'}. Best is trial 4 with value: 0.7806004618937644.
# [I 2024-05-20 17:19:46,213] Trial 6 finished with value: 0.7344110854503464 and parameters: {'hidden_size1': 256, 'hidden_size2': 55, 'lr': 0.019890473965261956, 'batch_size': 98, 'activation_function': 'relu'}. Best is trial 4 with value: 0.7806004618937644.
# [I 2024-05-20 17:20:00,314] Trial 7 finished with value: 0.6974595842956121 and parameters: {'hidden_size1': 198, 'hidden_size2': 117, 'lr': 0.00016181233757939096, 'batch_size': 89, 'activation_function': 'relu'}. Best is trial 4 with value: 0.7806004618937644.
# [I 2024-05-20 17:20:19,095] Trial 8 finished with value: 0.674364896073903 and parameters: {'hidden_size1': 69, 'hidden_size2': 127, 'lr': 0.024563080184829958, 'batch_size': 49, 'activation_function': 'relu'}. Best is trial 4 with value: 0.7806004618937644.
# [I 2024-05-20 17:20:33,041] Trial 9 finished with value: 0.5080831408775982 and parameters: {'hidden_size1': 221, 'hidden_size2': 71, 'lr': 1.4812513191980636e-05, 'batch_size': 96, 'activation_function': 'sigmoid'}. Best is trial 4 with value: 0.7806004618937644.
# [I 2024-05-20 17:21:10,062] Trial 10 finished with value: 0.7297921478060047 and parameters: {'hidden_size1': 157, 'hidden_size2': 97, 'lr': 0.00106074454925213, 'batch_size': 21, 'activation_function': 'tanh'}. Best is trial 4 with value: 0.7806004618937644.
# [I 2024-05-20 17:21:23,758] Trial 11 finished with value: 0.5080831408775982 and parameters: {'hidden_size1': 252, 'hidden_size2': 40, 'lr': 0.09709962061237853, 'batch_size': 119, 'activation_function': 'relu'}. Best is trial 4 with value: 0.7806004618937644.
# [I 2024-05-20 17:21:44,346] Trial 12 finished with value: 0.5080831408775982 and parameters: {'hidden_size1': 254, 'hidden_size2': 58, 'lr': 0.0350616161605108, 'batch_size': 48, 'activation_function': 'relu'}. Best is trial 4 with value: 0.7806004618937644.
# [I 2024-05-20 17:22:00,739] Trial 13 finished with value: 0.7274826789838337 and parameters: {'hidden_size1': 224, 'hidden_size2': 67, 'lr': 0.005643003230353801, 'batch_size': 67, 'activation_function': 'relu'}. Best is trial 4 with value: 0.7806004618937644.
# [I 2024-05-20 17:22:12,485] Trial 14 finished with value: 0.7598152424942263 and parameters: {'hidden_size1': 223, 'hidden_size2': 100, 'lr': 0.0017192333811522672, 'batch_size': 112, 'activation_function': 'relu'}. Best is trial 4 with value: 0.7806004618937644.
# [I 2024-05-20 17:22:37,311] Trial 15 finished with value: 0.6997690531177829 and parameters: {'hidden_size1': 167, 'hidden_size2': 103, 'lr': 0.0013733099703277106, 'batch_size': 37, 'activation_function': 'sigmoid'}. Best is trial 4 with value: 0.7806004618937644.
# [I 2024-05-20 17:22:49,996] Trial 16 finished with value: 0.7621247113163973 and parameters: {'hidden_size1': 220, 'hidden_size2': 109, 'lr': 0.002162197215536686, 'batch_size': 112, 'activation_function': 'relu'}. Best is trial 4 with value: 0.7806004618937644.
# [I 2024-05-20 17
 'activation_function': 'relu'}. Best is trial 4 with value: 0.7806004618937644.
# [I 2024-05-20 17:40:31,693] Trial 88 finished with value: 0.74364896073903 and parameters: {'hidden_size1': 79, 'hidden_size2': 118, 'lr': 0.0034961528333958118, 'batch_size': 44, 'activation_function': 'relu'}. Best is trial 4 with value: 0.7806004618937644.
# [I 2024-05-20 17:40:43,040] Trial 89 finished with value: 0.7528868360277137 and parameters: {'hidden_size1': 120, 'hidden_size2': 113, 'lr': 0.005148632344615882, 'batch_size': 122, 'activation_function': 'relu'}. Best is trial 4 with value: 0.7806004618937644.
# [I 2024-05-20 17:40:56,390] Trial 90 finished with value: 0.49191685912240185 and parameters: {'hidden_size1': 145, 'hidden_size2': 106, 'lr': 0.03556259080894169, 'batch_size': 108, 'activation_function': 'relu'}. Best is trial 4 with value: 0.7806004618937644.
# [I 2024-05-20 17:41:08,275] Trial 91 finished with value: 0.7806004618937644 and parameters: {'hidden_size1': 242, 'hidden_size2': 109, 'lr': 0.002601348998002472, 'batch_size': 112, 'activation_function': 'relu'}. Best is trial 4 with value: 0.7806004618937644.
# [I 2024-05-20 17:41:20,108] Trial 92 finished with value: 0.76905311778291 and parameters: {'hidden_size1': 241, 'hidden_size2': 112, 'lr': 0.0027043617433858253, 'batch_size': 112, 'activation_function': 'relu'}. Best is trial 4 with value: 0.7806004618937644.
# [I 2024-05-20 17:41:32,321] Trial 93 finished with value: 0.766743648960739 and parameters: {'hidden_size1': 242, 'hidden_size2': 121, 'lr': 0.002563462130425012, 'batch_size': 114, 'activation_function': 'relu'}. Best is trial 4 with value: 0.7806004618937644.
# [I 2024-05-20 17:41:43,861] Trial 94 finished with value: 0.7344110854503464 and parameters: {'hidden_size1': 234, 'hidden_size2': 120, 'lr': 0.0025189407948622445, 'batch_size': 114, 'activation_function': 'relu'}. Best is trial 4 with value: 0.7806004618937644.
# [I 2024-05-20 17:41:57,722] Trial 95 finished with value: 0.7644341801385681 and parameters: {'hidden_size1': 243, 'hidden_size2': 111, 'lr': 0.001418128332858676, 'batch_size': 104, 'activation_function': 'relu'}. Best is trial 4 with value: 0.7806004618937644.
# [I 2024-05-20 17:42:10,182] Trial 96 finished with value: 0.6073903002309469 and parameters: {'hidden_size1': 251, 'hidden_size2': 116, 'lr': 0.0008504234994377917, 'batch_size': 101, 'activation_function': 'sigmoid'}. Best is trial 4 with value: 0.7806004618937644.
# [I 2024-05-20 17:42:22,027] Trial 97 finished with value: 0.74364896073903 and parameters: {'hidden_size1': 240, 'hidden_size2': 119, 'lr': 0.0012066478133972327, 'batch_size': 112, 'activation_function': 'relu'}. Best is trial 4 with value: 0.7806004618937644.
# [I 2024-05-20 17:42:35,152] Trial 98 finished with value: 0.7321016166281755 and parameters: {'hidden_size1': 255, 'hidden_size2': 125, 'lr': 0.0021348085206454393, 'batch_size': 107, 'activation_function': 'relu'}. Best is trial 4 with value: 0.7806004618937644.
# [I 2024-05-20 17:42:49,605] Trial 99 finished with value: 0.7251732101616628 and parameters: {'hidden_size1': 245, 'hidden_size2': 109, 'lr': 0.0026527033821123033, 'batch_size': 87, 'activation_function': 'relu'}. Best is trial 4 with value: 0.7806004618937644.
# Best trial:
#   Value: 0.7806004618937644
#   Params:
#     hidden_size1: 223
#     hidden_size2: 123
#     lr: 0.009243325883276787
#     batch_size: 40
#     activation_function: relu

# %%
class SimpleNN(nn.Module):
    def __init__(self, input_size, hidden_size1, hidden_size2, output_size, activation_function):
        super(SimpleNN, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)
        self.fc3 = nn.Linear(hidden_size2, 20)
        self.fc4 = nn.Linear(20, output_size)
        activation_functions = {
            'relu': F.relu,
            'tanh': torch.tanh,
            'sigmoid': torch.sigmoid
        }
        self.activate = activation_functions[activation_function]

    def forward(self, x):
        x = self.activate(self.fc1(x))
        x = self.activate(self.fc2(x))
        x = self.activate(self.fc3(x))
        x = self.fc4(x)
        return x

# %%
# Second experiment

def objective(trial):
    hidden_size1 = trial.suggest_int('hidden_size1', 64, 256)
    hidden_size2 = trial.suggest_int('hidden_size2', 64, 256)
    lr = trial.suggest_float('lr', 1e-5, 1e-1, log=True)
    batch_size = trial.suggest_int('batch_size', 16, 128)
    activation_function = trial.suggest_categorical(
        'activation_function', ['relu', 'tanh', 'sigmoid'])

    model = SimpleNN(input_size=X_train.shape[1], hidden_size1=hidden_size1,
                     hidden_size2=hidden_size2, output_size=len(
                         np.unique(y_train)),
                     activation_function=activation_function).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer_algorithm = trial.suggest_categorical(
        'optimizer', ['adam', 'adamw', 'adamax', 'adadelta'])
    optimizers = {
        'adam': optim.Adam(model.parameters(), lr=lr),
        'adamw': optim.AdamW(model.parameters(), lr=lr),
        'adamax': optim.Adamax(model.parameters(), lr=lr),
        'adadelta': optim.Adadelta(model.parameters(), lr=lr)
    }
    optimizer = optimizers[optimizer_algorithm]

    optimizer = optim.Adam(model.parameters(), lr=lr)
    writer = SummaryWriter(
        f'runs/op_{hidden_size1}_{hidden_size2}_{lr}_{batch_size}')

    train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
    train_loader = DataLoader(
        train_dataset, batch_size=batch_size, shuffle=True)

    num_epochs = 100
    for epoch in range(num_epochs):
        model.train()
        for i, (inputs, labels) in enumerate(train_loader):
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            writer.add_scalar('training_loss', loss.item(),
                              epoch * len(train_loader) + i)

        model.eval()
        with torch.no_grad():
            predicted_outputs = model(X_test_tensor)
            _, predicted_classes = torch.max(predicted_outputs, 1)
            accuracy = (predicted_classes == y_test_tensor).sum(
            ).item() / y_test_tensor.size(0)
            writer.add_scalar('test_accuracy', accuracy, epoch)

        model.train()

    writer.close()
    return accuracy


study = optuna.create_study(
    study_name="active_function",
    storage='sqlite:///log.db',
    direction='maximize')
study.optimize(objective, n_trials=1000, n_jobs=10)

print("Best trial:")
trial = study.best_trial

print(f"  Value: {trial.value}")
print("  Params: ")
for key, value in trial.params.items():
    print(f"    {key}: {value}")
# Out:
# [I 2024-05-21 05:52:32,795] A new study created in RDB with name: active_function
# [I 2024-05-21 05:53:24,161] Trial 2 finished with value: 0.7482678983833718 and parameters: {'hidden_size1': 106, 'hidden_size2': 217, 'lr': 0.0034714406315490116, 'batch_size': 116, 'activation_function': 'tanh', 'optimizer': 'adamax'}. Best is trial 2 with value: 0.7482678983833718.
# [I 2024-05-21 05:53:29,961] Trial 0 finished with value: 0.5080831408775982 and parameters: {'hidden_size1': 232, 'hidden_size2': 185, 'lr': 1.5053612007965442e-05, 'batch_size': 104, 'activation_function': 'sigmoid', 'optimizer': 'adadelta'}. Best is trial 2 with value: 0.7482678983833718.
# [I 2024-05-21 05:53:37,340] Trial 4 finished with value: 0.7136258660508084 and parameters: {'hidden_size1': 137, 'hidden_size2': 92, 'lr': 0.0001770009938854068, 'batch_size': 87, 'activation_function': 'relu', 'optimizer': 'adamw'}. Best is trial 2 with value: 0.7482678983833718.
# [I 2024-05-21 05:54:04,187] Trial 3 finished with value: 0.6928406466512702 and parameters: {'hidden_size1': 228, 'hidden_size2': 165, 'lr': 3.445449089263628e-05, 'batch_size': 50, 'activation_function': 'tanh', 'optimizer': 'adamax'}. Best is trial 2 with value: 0.7482678983833718.
# [I 2024-05-21 05:54:20,500] Trial 7 finished with value: 0.7575057736720554 and parameters: {'hidden_size1': 154, 'hidden_size2': 133, 'lr': 0.01655513955518262, 'batch_size': 126, 'activation_function': 'relu', 'optimizer': 'adamw'}. Best is trial 7 with value: 0.7575057736720554.
# [I 2024-05-21 05:54:37,010] Trial 5 finished with value: 0.7505773672055427 and parameters: {'hidden_size1': 200, 'hidden_size2': 133, 'lr': 0.004175992375956134, 'batch_size': 67, 'activation_function': 'tanh', 'optimizer': 'adadelta'}. Best is trial 7 with value: 0.7575057736720554.
# [I 2024-05-21 05:54:48,605] Trial 8 finished with value: 0.7598152424942263 and parameters: {'hidden_size1': 194, 'hidden_size2': 127, 'lr': 0.006221432484255387, 'batch_size': 121, 'activation_function': 'tanh', 'optimizer': 'adam'}. Best is trial 8 with value: 0.7598152424942263.
# [I 2024-05-21 05:55:25,056] Trial 6 finished with value: 0.7182448036951501 and parameters: {'hidden_size1': 243, 'hidden_size2': 199, 'lr': 0.0167330092866092, 'batch_size': 41, 'activation_function': 'relu', 'optimizer': 'adamax'}. Best is trial 8 with value: 0.7598152424942263.
# [I 2024-05-21 05:55:45,173] Trial 9 finished with value: 0.7159353348729792 and parameters: {'hidden_size1': 249, 'hidden_size2': 233, 'lr': 0.006943875497949889, 'batch_size': 83, 'activation_function': 'sigmoid', 'optimizer': 'adamw'}. Best is trial 8 with value: 0.7598152424942263.
# [I 2024-05-21 05:55:49,500] Trial 1 finished with value: 0.5381062355658198 and parameters: {'hidden_size1': 207, 'hidden_size2': 210, 'lr': 9.786267732263757e-05, 'batch_size': 24, 'activation_function': 'sigmoid', 'optimizer': 'adam'}. Best is trial 8 with value: 0.7598152424942263.
# [I 2024-05-21 05:56:19,528] Trial 11 finished with value: 0.5750577367205543 and parameters: {'hidden_size1': 250, 'hidden_size2': 254, 'lr': 0.0016693832006272854, 'batch_size': 72, 'activation_function': 'sigmoid', 'optimizer': 'adam'}. Best is trial 8 with value: 0.7598152424942263.
# [I 2024-05-21 05:56:21,988] Trial 10 finished with value: 0.7367205542725174 and parameters: {'hidden_size1': 153, 'hidden_size2': 159, 'lr': 0.0011830730591702173, 'batch_size': 60, 'activation_function': 'tanh', 'optimizer': 'adamw'}. Best is trial 8 with value: 0.7598152424942263.
# [I 2024-05-21 05:56:41,210] Trial 14 finished with value: 0.5080831408775982 and parameters: {'hidden_size1': 74, 'hidden_size2': 67, 'lr': 0.08151882070125982, 'batch_size': 98, 'activation_function': 'tanh', 'optimizer': 'adam'}. Best is trial 8 with value: 0.7598152424942263.
# [I 2024-05-21 05:56:43,877] Trial 12 finished with value: 0.5080831408775982 and parameters: {'hidden_size1': 235, 'hidden_size2': 149, 'lr': 0.03040970445579288, 'batch_size': 81, 'activation_function': 'sigmoid', 'optimizer': 'adamax'}. Best is trial 8 with value: 0.7598152424942263.
# [I 2024-05-21 05:57:02,985] Trial 13 finished with value: 0.7551963048498845 and parameters: {'hidden_size1': 128, 'hidden_size2': 118, 'lr': 0.0027841847183432173, 'batch_size': 66, 'activation_function': 'relu', 'optimizer': 'adamw'}. Best is trial 8 with value: 0.7598152424942263.
# [I 2024-05-21 05:57:08,387] Trial 15 finished with value: 0.5080831408775982 and parameters: {'hidden_size1': 158, 'hidden_size2': 124, 'lr': 0.09051821681053497, 'batch_size': 125, 'activation_function': 'relu', 'optimizer': 'adamw'}. Best is trial 8 with value: 0.7598152424942263.
# [I 2024-05-21 05:57:10,249] Trial 16 finished with value: 0.5080831408775982 and parameters: {'hidden_size1': 178, 'hidden_size2': 106, 'lr': 0.07330119426672496, 'batch_size': 128, 'activation_function': 'relu', 'optimizer': 'adam'}. Best is trial 8 with value: 0.7598152424942263.
# [I 2024-05-21 05:57:30,128] Trial 17 finished with value: 0.7321016166281755 and parameters: {'hidden_size1': 185, 'hidden_size2': 119, 'lr': 0.041758906738687124, 'batch_size': 121, 'activation_function': 'relu', 'optimizer': 'adamw'}. Best is trial 8 with value: 0.7598152424942263.
# [I 2024-05-21 05:57:33,482] Trial 18 finished with value: 0.7274826789838337 and parameters: {'hidden_size1': 181, 'hidden_size2': 122, 'lr': 0.0004495103558164466, 'batch_size': 126, 'activation_function': 'relu', 'optimizer': 'adam'}. Best is trial 8 with value: 0.7598152424942263.
# [I 2024-05-21 05:57:54,029] Trial 19 finished with value: 0.7205542725173211 and parameters: {'hidden_size1': 180, 'hidden_size2': 114, 'lr': 0.0003374620133514152, 'batch_size': 127, 'activation_function': 'relu', 'optimizer': 'adam'}. Best is trial 8 with value: 0.7598152424942263.
# [I 2024-05-21 05:58:02,082] Trial 20 finished with value: 0.74364896073903 and parameters: {'hidden_size1': 183, 'hidden_size2': 101, 'lr': 0.014761186979814487, 'batch_size': 123, 'activation_function': 'relu', 'optimizer': 'adam'}. Best is trial 8 with value: 0.7598152424942263.
# [I 2024-05-21 05:58:17,452] Trial 21 finished with value: 0.7367205542725174 and parameters: {'hidden_size1': 186, 'hidden_size2': 86, 'lr': 0.00036279866351282634, 'batch_size': 110, 'activation_function': 'relu', 'optimizer': 'adam'}. Best is trial 8 with value: 0.7598152424942263.
# [I 2024-05-21 06:00:19,617] Trial 22 finished with value: 0.6420323325635104 and parameters: {'hidden_size1': 101, 'hidden_size2': 81, 'lr': 0.010197661734812048, 'batch_size': 107, 'activation_function': 'tanh', 'optimizer': 'adam'}. Best is trial 8 with value: 0.7598152424942263.
# [I 2024-05-21 06:00:26,629] Trial 23 finished with value: 0.5080831408775982 and parameters: {'hidden_size1': 100, 'hidden_size2': 85, 'lr': 0.018138821980430937, 'batch_size': 108, 'activation_function': 'tanh', 'optimizer': 'adadelta'}. Best is trial 8 with value: 0.7598152424942263.
# [I 2024-05-21 06:01:17,811] Trial 24 finished with value: 0.7321016166281755 and parameters: {'hidden_size1': 106, 'hidden_size2': 79, 'lr': 0.009080692021768593, 'batch_size': 107, 'activation_function': 'tanh', 'optimizer': 'adadelta'}. Best is trial 8 with value: 0.7598152424942263.
# [I 2024-05-21 06:01:22,329] Trial 25 finished with value: 0.7043879907621247 and parameters: {'hidden_size1': 119, 'hidden_size2': 80, 'lr': 0.008603100988454664, 'batch_size': 108, 'activation_function': 'tanh', 'optimizer': 'adamw'}. Best is trial 8 with value: 0.7598152424942263.
# [I 2024-05-21 06:01:30,040] Trial 26 finished with value: 0.7528868360277137 and parameters: {'hidden_size1': 126, 'hidden_size2': 144, 'lr': 0.008158717958167467, 'batch_size': 100, 'activation_function': 'tanh', 'optimizer': 'adamw'}. Best is trial 8 with value: 0.7598152424942263.
# [I 2024-05-21 06:01:53,670] Trial 27 finished with value: 0.7621247113163973 and parameters: {'hidden_size1': 132, 'hidden_size2': 142, 'lr': 0.0022324862962425744, 'batch_size': 95, 'activation_function': 'relu', 'optimizer': 'adamw'}. Best is trial 27 with value: 0.7621247113163973.
# [I 2024-05-21 06:01:57,126] Trial 28 finished with value: 0.7413394919168591 and parameters: {'hidden_size1': 132, 'hidden_size2': 144, 'lr': 0.003036902907935002, 'batch_size': 97, 'activation_function': 'relu', 'optimizer': 'adamw'}. Best is trial 27 with value: 0.7621247113163973.
# [I 2024-05-21 06:02:20,450] Trial 29 finished with value: 0.7505773672055427 and parameters: {'hidden_size1': 141, 'hidden_size2': 144, 'lr': 0.0023214585753220406, 'batch_size': 96, 'activation_function': 'relu', 'optimizer': 'adamw'}. Best is trial 27 with value: 0.7621247113163973.
# [I 2024-05-21 06:02:24,526] Trial 30 finished with value: 0.7575057736720554 and parameters: {'hidden_size1': 133, 'hidden_size2': 135, 'lr': 0.0025465210948151565, 'batch_size': 94, 'activation_function': 'relu', 'optimizer': 'adamw'}. Best is trial 27 with value: 0.7621247113163973.
# [I 2024-05-21 06:02:34,559] Trial 31 finished with value: 0.7413394919168591 and parameters: {'hidden_size1': 150, 'hidden_size2': 174, 'lr': 0.0029957827860177407, 'batch_size': 92, 'activation_function': 'relu', 'optimizer': 'adamw'}. Best is trial 27 with value: 0.7621247113163973.
# [I 2024-05-21 06:02:54,196] Trial 32 finished with value: 0.7551963048498845 and parameters: {'hidden_size1': 145, 'hidden_size2': 178, 'lr': 0.0015994652173339679, 'batch_size': 93, 'activation_function': 'relu', 'optimizer': 'adamw'}. Best is trial 27 with value: 0.7621247113163973.
# [I 2024-05-21 06:03:02,180] Trial 33 finished with value: 0.7297921478060047 and parameters: {'hidden_size1': 144, 'hidden_size2': 177, 'lr': 0.0006533462633819162, 'batch_size': 90, 'activation_function': 'relu', 'optimizer': 'adamw'}. Best is trial 27 with value: 0.7621247113163973.
# [I 2024-05-21 06:03:16,979] Trial 34 finished with value: 0.74364896073903 and parameters: {'hidden_size1': 209, 'hidden_size2': 179, 'lr': 0.0008287853685324392, 'batch_size': 114, 'activation_function': 'relu', 'optimizer': 'adadelta'}. Best is trial 27 with value: 0.7621247113163973.
# [I 2024-05-21 06:03:20,532] Trial 35 finished with value: 0.7205542725173211 and parameters: {'hidden_size1': 150, 'hidden_size2': 165, 'lr': 0.0005998834903076766, 'batch_size': 115, 'activation_function': 'relu', 'optimizer': 'adamw'}. Best is trial 27 with value: 0.7621247113163973.
# [I 2024-05-21 06:03:54,846] Trial 36 finished with value: 0.7413394919168591 and parameters: {'hidden_size1': 166, 'hidden_size2': 132, 'lr': 0.0008837201597794616, 'batch_size': 115, 'activation_function': 'relu', 'optimizer': 'adamw'}. Best is trial 27 with value: 0.7621247113163973.
# [I 2024-05-21 06:05:41,985] Trial 37 finished with value: 0.5935334872979214 and parameters: {'hidden_size1': 164, 'hidden_size2': 134, 'lr': 0.0006959292992667103, 'batch_size': 117, 'activation_function': 'sigmoid', 'optimizer': 'adamw'}. Best is trial 27 with value: 0.7621247113163973.
# [I 2024-05-21 06:06:19,963] Trial 38 finished with value: 0.5796766743648961 and parameters: {'hidden_size1': 168, 'hidden_size2': 134, 'lr': 0.0008113041105032642, 'batch_size': 115, 'activation_function': 'sigmoid', 'optimizer': 'adamw'}. Best is trial 27 with value: 0.7621247113163973.
# [I 2024-05-21 06:07:07,328] Trial 39 finished with value: 0.6882217090069284 and parameters: {'hidden_size1': 172, 'hidden_size2': 134, 'lr': 0.005135913317646589, 'batch_size': 114, 'activation_function': 'sigmoid', 'optimizer': 'adamw'}. Best is trial 27 with value: 0.7621247113163973.
# [I 2024-05-21 06:07:47,574] Trial 41 finished with value: 0.7066974595842956 and parameters: {'hidden_size1': 215, 'hidden_size2': 195, 'lr': 0.0047246875464928085, 'batch_size': 76, 'activation_function': 'sigmoid', 'optimizer': 'adamax'}. Best is trial 27 with value: 0.7621247113163973.
# [I 2024-05-21 06:08:01,826] Trial 42 finished with value: 0.5080831408775982 and parameters: {'hidden_size1': 201, 'hidden_size2': 192, 'lr': 0.005383847698668266, 'batch_size': 81, 'activation_function': 'sigmoid', 'optimizer': 'adamax'}. Best is trial 27 with value: 0.7621247113163973.
# [I 2024-05-21 06:08:20,563] Trial 44 finished with value: 0.5704387990762124 and parameters: {'hidden_size1': 211, 'hidden_size2': 198, 'lr': 1.3642940374097289e-05, 'batch_size': 82, 'activation_function': 'tanh', 'optimizer': 'adamax'}. Best is trial 27 with value: 0.7621247113163973.
# [I 2024-05-21 06:09:11,820] Trial 46 finished with value: 0.7205542725173211 and parameters: {'hidden_size1': 120, 'hidden_size2': 156, 'lr': 0.00012220998624591894, 'batch_size': 60, 'activation_function': 'relu', 'optimizer': 'adamw'}. Best is trial 27 with value: 0.7621247113163973.
# [I 2024-05-21 06:09:23,515] Trial 45 finished with value: 0.5981524249422633 and parameters: {'hidden_size1': 116, 'hidden_size2': 156, 'lr': 3.2404022286821514e-05, 'batch_size': 46, 'activation_function': 'relu', 'optimizer': 'adamw'}. Best is trial 27 with value: 0.7621247113163973.
# [I 2024-05-21 06:09:42,988] Trial 47 finished with value: 0.7251732101616628 and parameters: {'hidden_size1': 116, 'hidden_size2': 108, 'lr': 0.001910841989829442, 'batch_size': 54, 'activation_function': 'relu', 'optimizer': 'adamw'}. Best is trial 27 with value: 0.7621247113163973.
# [I 2024-05-21 06:09:56,830] Trial 40 finished with value: 0.5080831408775982 and parameters: {'hidden_size1': 168, 'hidden_size2': 133, 'lr': 1.8411799286802584e-05, 'batch_size': 19, 'activation_function': 'sigmoid', 'optimizer': 'adamax'}. Best is trial 27 with value: 0.7621247113163973.
# [I 2024-05-21 06:10:00,242] Trial 43 finished with value: 0.7228637413394919 and parameters: {'hidden_size1': 217, 'hidden_size2': 198, 'lr': 0.0054480999106272555, 'batch_size': 23, 'activation_function': 'tanh', 'optimizer': 'adamax'}. Best is trial 27 with value: 0.7621247113163973.
# [I 2024-05-21 06:10:54,608] Trial 48 finished with value: 0.7482678983833718 and parameters: {'hidden_size1': 88, 'hidden_size2': 107, 'lr': 0.00201055102294539, 'batch_size': 43, 'activation_function': 'relu', 'optimizer': 'adamw'}. Best is trial 27 with value: 0.7621247113163973.
# [I 2024-05-21 06:11:05,947] Trial 51 finished with value: 0.7575057736720554 and parameters: {'hidden_size1': 91, 'hidden_size2': 94, 'lr': 0.027182845955658768, 'batch_size': 66, 'activation_function': 'relu', 'optimizer': 'adadelta'}. Best is trial 27 with value: 0.7621247113163973.
# [I 2024-05-21 06
 'activation_function': 'tanh', 'optimizer': 'adam'}. Best is trial 77 with value: 0.7806004618937644.
# [I 2024-05-21 06:53:11,434] Trial 98 finished with value: 0.7782909930715936 and parameters: {'hidden_size1': 249, 'hidden_size2': 215, 'lr': 0.0029918252579089247, 'batch_size': 95, 'activation_function': 'tanh', 'optimizer': 'adam'}. Best is trial 77 with value: 0.7806004618937644.
# [I 2024-05-21 06:53:11,882] Trial 97 finished with value: 0.7205542725173211 and parameters: {'hidden_size1': 248, 'hidden_size2': 211, 'lr': 0.0017265775868326937, 'batch_size': 85, 'activation_function': 'tanh', 'optimizer': 'adam'}. Best is trial 77 with value: 0.7806004618937644.
# [I 2024-05-21 06:53:15,239] Trial 99 finished with value: 0.7390300230946882 and parameters: {'hidden_size1': 251, 'hidden_size2': 225, 'lr': 0.0010920271758204801, 'batch_size': 78, 'activation_function': 'tanh', 'optimizer': 'adam'}. Best is trial 77 with value: 0.7806004618937644.
# Best trial:
#   Value: 0.7806004618937644
#   Params:
#     hidden_size1: 240
#     hidden_size2: 138
#     lr: 0.0040303667072265625
#     batch_size: 111
#     activation_function: tanh
#     optimizer: adam

# %% [markdown]
# # Tuning

# %%
class DenseNN(nn.Module):
    def __init__(self,  layer_sizes, activation_function):
        super(DenseNN, self).__init__()
        self.densebois = nn.ModuleList()
        for i in range(1, len(layer_sizes)):
            self.densebois.append(
                nn.Linear(layer_sizes[i - 1], layer_sizes[i]))
        activation_functions = {
            'relu': F.relu,
            'tanh': torch.tanh,
            'sigmoid': torch.sigmoid
        }
        self.activate = activation_functions[activation_function]

    def forward(self, x):
        for layer in self.densebois[:-1]:
            x = self.activate(layer(x))
        x = self.densebois[-1](x)
        return x

# %%
def objective(trial):
    num_layers = trial.suggest_int('num_layers', 2, 5)
    layer_sizes = [X_train.shape[1]]
    batch_size = trial.suggest_int('batch_size', 16, 256)

    for i in range(num_layers - 1):
        layer_sizes.append(trial.suggest_int(f'layer_size_{i+1}', 64, 256))

    layer_sizes.append(len(np.unique(y_train)))

    activation_function = trial.suggest_categorical(
        'activation_function', ['relu', 'tanh', 'sigmoid'])

    model = DenseNN(layer_sizes=layer_sizes,
                    activation_function=activation_function).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer_algorithm = trial.suggest_categorical(
        'optimizer', ['adam', 'adamw', 'adamax', 'adadelta'])
    lr = trial.suggest_float('lr', 1e-5, 1e-1, log=True)
    optimizers = {
        'adam': optim.Adam(model.parameters(), lr=lr),
        'adamw': optim.AdamW(model.parameters(), lr=lr),
        'adamax': optim.Adamax(model.parameters(), lr=lr),
        'adadelta': optim.Adadelta(model.parameters(), lr=lr)
    }
    optimizer = optimizers[optimizer_algorithm]

    writer = SummaryWriter(f'runs/op_{layer_sizes}_{lr}_{batch_size}')

    train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
    train_loader = DataLoader(
        train_dataset, batch_size=batch_size, shuffle=True)

    num_epochs = 100
    for epoch in range(num_epochs):
        model.train()
        for i, (inputs, labels) in enumerate(train_loader):
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            writer.add_scalar('training_loss', loss.item(),
                              epoch * len(train_loader) + i)

        model.eval()
        with torch.no_grad():
            predicted_outputs = model(X_test_tensor)
            _, predicted_classes = torch.max(predicted_outputs, 1)
            accuracy = (predicted_classes == y_test_tensor).sum(
            ).item() / y_test_tensor.size(0)
            writer.add_scalar('test_accuracy', accuracy, epoch)

        model.train()

    writer.close()
    return accuracy


study = optuna.create_study(study_name="dynamic_layers",
                            storage='sqlite:///log.db',
                            direction='maximize', load_if_exists=True)
study.optimize(objective, n_trials=1000, n_jobs=10)

print("Best trial:")
trial = study.best_trial

print(f"  Value: {trial.value}")
print("  Params: ")
for key, value in trial.params.items():
    print(f"    {key}: {value}")
# Out:
# [I 2024-05-23 06:48:24,611] Using an existing study with name 'dynamic_layers' instead of creating a new one.
# [I 2024-05-23 06:55:48,193] Trial 914 finished with value: 0.7113163972286374 and parameters: {'num_layers': 4, 'batch_size': 168, 'layer_size_1': 239, 'layer_size_2': 131, 'layer_size_3': 113, 'activation_function': 'tanh', 'optimizer': 'adamw', 'lr': 0.0002743431775195438}. Best is trial 914 with value: 0.7113163972286374.
# [I 2024-05-23 06:55:55,212] Trial 915 finished with value: 0.7274826789838337 and parameters: {'num_layers': 4, 'batch_size': 168, 'layer_size_1': 245, 'layer_size_2': 135, 'layer_size_3': 164, 'activation_function': 'relu', 'optimizer': 'adamw', 'lr': 0.00027477624954491735}. Best is trial 915 with value: 0.7274826789838337.
# [I 2024-05-23 06:55:57,492] Trial 918 finished with value: 0.7274826789838337 and parameters: {'num_layers': 4, 'batch_size': 168, 'layer_size_1': 246, 'layer_size_2': 130, 'layer_size_3': 114, 'activation_function': 'tanh', 'optimizer': 'adamw', 'lr': 0.00028488548792179956}. Best is trial 915 with value: 0.7274826789838337.
# [I 2024-05-23 06:56:29,751] Trial 910 finished with value: 0.7159353348729792 and parameters: {'num_layers': 4, 'batch_size': 145, 'layer_size_1': 246, 'layer_size_2': 88, 'layer_size_3': 126, 'activation_function': 'tanh', 'optimizer': 'adamw', 'lr': 0.00027730878710878265}. Best is trial 915 with value: 0.7274826789838337.
# [I 2024-05-23 06:56:34,859] Trial 917 finished with value: 0.7344110854503464 and parameters: {'num_layers': 4, 'batch_size': 145, 'layer_size_1': 238, 'layer_size_2': 132, 'layer_size_3': 127, 'activation_function': 'relu', 'optimizer': 'adamw', 'lr': 0.00027188390205893677}. Best is trial 917 with value: 0.7344110854503464.
# [I 2024-05-23 06:57:11,972] Trial 911 finished with value: 0.6905311778290993 and parameters: {'num_layers': 4, 'batch_size': 144, 'layer_size_1': 246, 'layer_size_2': 131, 'layer_size_3': 164, 'activation_function': 'tanh', 'optimizer': 'adamw', 'lr': 0.0002707056926239865}. Best is trial 917 with value: 0.7344110854503464.
# [I 2024-05-23 06:57:15,509] Trial 913 finished with value: 0.7344110854503464 and parameters: {'num_layers': 4, 'batch_size': 143, 'layer_size_1': 245, 'layer_size_2': 133, 'layer_size_3': 113, 'activation_function': 'relu', 'optimizer': 'adamw', 'lr': 0.0002903758623416112}. Best is trial 913 with value: 0.7344110854503464.
# [I 2024-05-23 06:58:10,596] Trial 912 finished with value: 0.7159353348729792 and parameters: {'num_layers': 4, 'batch_size': 122, 'layer_size_1': 246, 'layer_size_2': 130, 'layer_size_3': 127, 'activation_function': 'tanh', 'optimizer': 'adamw', 'lr': 0.00027529884395990803}. Best is trial 913 with value: 0.7344110854503464.
# [I 2024-05-23 06:58:22,052] Trial 916 finished with value: 0.7367205542725174 and parameters: {'num_layers': 4, 'batch_size': 123, 'layer_size_1': 239, 'layer_size_2': 132, 'layer_size_3': 111, 'activation_function': 'tanh', 'optimizer': 'adamw', 'lr': 0.00028440287267252637}. Best is trial 916 with value: 0.7367205542725174.
# [I 2024-05-23 06:58:35,383] Trial 919 finished with value: 0.7621247113163973 and parameters: {'num_layers': 4, 'batch_size': 123, 'layer_size_1': 245, 'layer_size_2': 130, 'layer_size_3': 163, 'activation_function': 'relu', 'optimizer': 'adamw', 'lr': 0.00043412544276228793}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 07:08:57,421] Trial 920 finished with value: 0.625866050808314 and parameters: {'num_layers': 4, 'batch_size': 179, 'layer_size_1': 246, 'layer_size_2': 136, 'layer_size_3': 128, 'activation_function': 'relu', 'optimizer': 'adamax', 'lr': 0.00018097974262765718}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 07:09:28,027] Trial 922 finished with value: 0.7020785219399538 and parameters: {'num_layers': 4, 'batch_size': 180, 'layer_size_1': 248, 'layer_size_2': 130, 'layer_size_3': 163, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00020438017852442147}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 07:09:51,167] Trial 921 finished with value: 0.6974595842956121 and parameters: {'num_layers': 4, 'batch_size': 169, 'layer_size_1': 252, 'layer_size_2': 131, 'layer_size_3': 170, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00019345242227899824}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 07:10:16,658] Trial 923 finished with value: 0.6905311778290993 and parameters: {'num_layers': 4, 'batch_size': 173, 'layer_size_1': 247, 'layer_size_2': 131, 'layer_size_3': 158, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00022672599623060078}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 07:12:48,701] Trial 924 finished with value: 0.7159353348729792 and parameters: {'num_layers': 4, 'batch_size': 179, 'layer_size_1': 245, 'layer_size_2': 130, 'layer_size_3': 129, 'activation_function': 'tanh', 'optimizer': 'adamw', 'lr': 0.00019105050820416634}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 07:13:12,717] Trial 925 finished with value: 0.7321016166281755 and parameters: {'num_layers': 4, 'batch_size': 169, 'layer_size_1': 246, 'layer_size_2': 86, 'layer_size_3': 170, 'activation_function': 'tanh', 'optimizer': 'adamw', 'lr': 0.0001852729458190368}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 07:13:25,953] Trial 926 finished with value: 0.7297921478060047 and parameters: {'num_layers': 4, 'batch_size': 170, 'layer_size_1': 246, 'layer_size_2': 130, 'layer_size_3': 166, 'activation_function': 'tanh', 'optimizer': 'adamw', 'lr': 0.00018734833770470892}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 07:14:39,336] Trial 928 finished with value: 0.6951501154734411 and parameters: {'num_layers': 4, 'batch_size': 171, 'layer_size_1': 246, 'layer_size_2': 131, 'layer_size_3': 165, 'activation_function': 'tanh', 'optimizer': 'adamw', 'lr': 0.00020147507548013406}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 07:15:34,694] Trial 927 finished with value: 0.6581986143187067 and parameters: {'num_layers': 4, 'batch_size': 162, 'layer_size_1': 247, 'layer_size_2': 84, 'layer_size_3': 162, 'activation_function': 'tanh', 'optimizer': 'adamw', 'lr': 0.00017950206592030137}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 07:16:11,312] Trial 929 finished with value: 0.6789838337182448 and parameters: {'num_layers': 4, 'batch_size': 156, 'layer_size_1': 251, 'layer_size_2': 79, 'layer_size_3': 168, 'activation_function': 'tanh', 'optimizer': 'adamw', 'lr': 0.00018647859377943414}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 07:25:45,463] Trial 931 finished with value: 0.7020785219399538 and parameters: {'num_layers': 4, 'batch_size': 172, 'layer_size_1': 253, 'layer_size_2': 130, 'layer_size_3': 164, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00020996814098792673}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 07:26:04,088] Trial 933 finished with value: 0.6997690531177829 and parameters: {'num_layers': 4, 'batch_size': 168, 'layer_size_1': 252, 'layer_size_2': 129, 'layer_size_3': 164, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00023450047459566855}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 07:26:14,346] Trial 932 finished with value: 0.6905311778290993 and parameters: {'num_layers': 4, 'batch_size': 177, 'layer_size_1': 251, 'layer_size_2': 131, 'layer_size_3': 172, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.0001732745307370268}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 07:27:20,623] Trial 930 finished with value: 0.7321016166281755 and parameters: {'num_layers': 4, 'batch_size': 166, 'layer_size_1': 251, 'layer_size_2': 131, 'layer_size_3': 174, 'activation_function': 'tanh', 'optimizer': 'adamw', 'lr': 0.00021536269686875322}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 07:28:51,215] Trial 935 finished with value: 0.648960739030023 and parameters: {'num_layers': 4, 'batch_size': 166, 'layer_size_1': 253, 'layer_size_2': 130, 'layer_size_3': 173, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 9.663134826416087e-05}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 07:28:59,597] Trial 934 finished with value: 0.7066974595842956 and parameters: {'num_layers': 4, 'batch_size': 168, 'layer_size_1': 252, 'layer_size_2': 130, 'layer_size_3': 171, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00016350803628669108}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 07:29:09,351] Trial 936 finished with value: 0.6974595842956121 and parameters: {'num_layers': 4, 'batch_size': 168, 'layer_size_1': 253, 'layer_size_2': 129, 'layer_size_3': 169, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00016088974720221487}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 07:30:23,846] Trial 937 finished with value: 0.6651270207852193 and parameters: {'num_layers': 4, 'batch_size': 170, 'layer_size_1': 251, 'layer_size_2': 129, 'layer_size_3': 174, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 9.794907535654241e-05}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 07:31:11,456] Trial 938 finished with value: 0.674364896073903 and parameters: {'num_layers': 4, 'batch_size': 169, 'layer_size_1': 253, 'layer_size_2': 129, 'layer_size_3': 169, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00012656082870242624}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 07:31:52,922] Trial 939 finished with value: 0.6605080831408776 and parameters: {'num_layers': 4, 'batch_size': 169, 'layer_size_1': 256, 'layer_size_2': 129, 'layer_size_3': 164, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.0001130094092540266}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 07:42:30,573] Trial 940 finished with value: 0.6928406466512702 and parameters: {'num_layers': 4, 'batch_size': 169, 'layer_size_1': 254, 'layer_size_2': 129, 'layer_size_3': 167, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.0001621131091851043}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 07:42:33,217] Trial 941 finished with value: 0.6928406466512702 and parameters: {'num_layers': 4, 'batch_size': 168, 'layer_size_1': 253, 'layer_size_2': 129, 'layer_size_3': 171, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00014216798932812648}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 07:43:10,794] Trial 942 finished with value: 0.6997690531177829 and parameters: {'num_layers': 4, 'batch_size': 166, 'layer_size_1': 256, 'layer_size_2': 130, 'layer_size_3': 169, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00011802785433596489}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 07:44:51,859] Trial 943 finished with value: 0.6951501154734411 and parameters: {'num_layers': 4, 'batch_size': 170, 'layer_size_1': 256, 'layer_size_2': 130, 'layer_size_3': 172, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.0001472656567841394}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 07:46:12,215] Trial 944 finished with value: 0.6905311778290993 and parameters: {'num_layers': 4, 'batch_size': 165, 'layer_size_1': 251, 'layer_size_2': 129, 'layer_size_3': 169, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00013247466277422498}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 07
-05}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 08:46:51,499] Trial 960 finished with value: 0.6420323325635104 and parameters: {'num_layers': 4, 'batch_size': 175, 'layer_size_1': 251, 'layer_size_2': 133, 'layer_size_3': 175, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 9.89226477819138e-05}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 08:47:29,300] Trial 961 finished with value: 0.6027713625866051 and parameters: {'num_layers': 4, 'batch_size': 175, 'layer_size_1': 256, 'layer_size_2': 125, 'layer_size_3': 174, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 7.515271325518014e-05}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 08:48:52,893] Trial 962 finished with value: 0.6166281755196305 and parameters: {'num_layers': 4, 'batch_size': 175, 'layer_size_1': 256, 'layer_size_2': 125, 'layer_size_3': 183, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 6.312803575144968e-05}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 08:49:51,049] Trial 964 finished with value: 0.6628175519630485 and parameters: {'num_layers': 4, 'batch_size': 176, 'layer_size_1': 250, 'layer_size_2': 175, 'layer_size_3': 183, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 8.352629855295607e-05}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 08:50:02,933] Trial 963 finished with value: 0.6189376443418014 and parameters: {'num_layers': 4, 'batch_size': 175, 'layer_size_1': 250, 'layer_size_2': 133, 'layer_size_3': 166, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 7.046525931955073e-05}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 08:50:29,011] Trial 965 finished with value: 0.6605080831408776 and parameters: {'num_layers': 4, 'batch_size': 177, 'layer_size_1': 250, 'layer_size_2': 189, 'layer_size_3': 164, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00010372664218936045}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 08:51:04,484] Trial 967 finished with value: 0.5912240184757506 and parameters: {'num_layers': 4, 'batch_size': 176, 'layer_size_1': 249, 'layer_size_2': 124, 'layer_size_3': 182, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 5.878673917135315e-05}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 08:51:12,780] Trial 968 finished with value: 0.6951501154734411 and parameters: {'num_layers': 4, 'batch_size': 179, 'layer_size_1': 250, 'layer_size_2': 189, 'layer_size_3': 165, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.0001684684045058467}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 08:51:21,081] Trial 966 finished with value: 0.6374133949191686 and parameters: {'num_layers': 4, 'batch_size': 178, 'layer_size_1': 250, 'layer_size_2': 182, 'layer_size_3': 164, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 7.654482242204892e-05}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 08:52:08,936] Trial 969 finished with value: 0.5912240184757506 and parameters: {'num_layers': 4, 'batch_size': 178, 'layer_size_1': 250, 'layer_size_2': 170, 'layer_size_3': 184, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 6.52171534978544e-05}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 09:04:06,396] Trial 970 finished with value: 0.6997690531177829 and parameters: {'num_layers': 4, 'batch_size': 164, 'layer_size_1': 250, 'layer_size_2': 176, 'layer_size_3': 184, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.0001653714920922272}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 09:05:22,517] Trial 971 finished with value: 0.628175519630485 and parameters: {'num_layers': 4, 'batch_size': 161, 'layer_size_1': 250, 'layer_size_2': 174, 'layer_size_3': 166, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00016574044555293062}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 09:06:52,437] Trial 972 finished with value: 0.6882217090069284 and parameters: {'num_layers': 4, 'batch_size': 160, 'layer_size_1': 251, 'layer_size_2': 192, 'layer_size_3': 164, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.0001653104619331179}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 09:07:20,043] Trial 974 finished with value: 0.6905311778290993 and parameters: {'num_layers': 4, 'batch_size': 164, 'layer_size_1': 249, 'layer_size_2': 127, 'layer_size_3': 165, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00016201428686197472}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 09:07:44,635] Trial 973 finished with value: 0.581986143187067 and parameters: {'num_layers': 4, 'batch_size': 162, 'layer_size_1': 251, 'layer_size_2': 126, 'layer_size_3': 164, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.0001642673770790293}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 09:08:13,995] Trial 975 finished with value: 0.6189376443418014 and parameters: {'num_layers': 4, 'batch_size': 161, 'layer_size_1': 249, 'layer_size_2': 126, 'layer_size_3': 162, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00016597405103127138}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 09:08:27,882] Trial 979 finished with value: 0.6951501154734411 and parameters: {'num_layers': 4, 'batch_size': 163, 'layer_size_1': 248, 'layer_size_2': 126, 'layer_size_3': 168, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00015735078103765442}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 09:08:31,580] Trial 976 finished with value: 0.6697459584295612 and parameters: {'num_layers': 4, 'batch_size': 161, 'layer_size_1': 249, 'layer_size_2': 194, 'layer_size_3': 162, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00017172231640702102}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 09:08:37,450] Trial 977 finished with value: 0.6004618937644342 and parameters: {'num_layers': 4, 'batch_size': 161, 'layer_size_1': 248, 'layer_size_2': 126, 'layer_size_3': 162, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.0001678352246364326}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 09:09:30,577] Trial 978 finished with value: 0.6628175519630485 and parameters: {'num_layers': 4, 'batch_size': 161, 'layer_size_1': 251, 'layer_size_2': 126, 'layer_size_3': 170, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00017076105304614705}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 09:23:52,701] Trial 981 finished with value: 0.6974595842956121 and parameters: {'num_layers': 4, 'batch_size': 163, 'layer_size_1': 248, 'layer_size_2': 172, 'layer_size_3': 170, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00016561210190179783}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 09:24:20,873] Trial 980 finished with value: 0.6836027713625866 and parameters: {'num_layers': 4, 'batch_size': 160, 'layer_size_1': 249, 'layer_size_2': 179, 'layer_size_3': 190, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.0001597630261770153}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 09:26:04,798] Trial 982 finished with value: 0.7020785219399538 and parameters: {'num_layers': 4, 'batch_size': 164, 'layer_size_1': 248, 'layer_size_2': 172, 'layer_size_3': 186, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.000164620926484315}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 09:26:58,504] Trial 983 finished with value: 0.6651270207852193 and parameters: {'num_layers': 4, 'batch_size': 163, 'layer_size_1': 248, 'layer_size_2': 126, 'layer_size_3': 188, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00011022060658096433}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 09:27:44,237] Trial 986 finished with value: 0.6882217090069284 and parameters: {'num_layers': 4, 'batch_size': 166, 'layer_size_1': 246, 'layer_size_2': 182, 'layer_size_3': 192, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.0001249375327231498}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 09:27:50,580] Trial 988 finished with value: 0.6836027713625866 and parameters: {'num_layers': 4, 'batch_size': 166, 'layer_size_1': 252, 'layer_size_2': 135, 'layer_size_3': 173, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00011881701250070597}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 09:27:53,885] Trial 985 finished with value: 0.6812933025404158 and parameters: {'num_layers': 4, 'batch_size': 165, 'layer_size_1': 247, 'layer_size_2': 185, 'layer_size_3': 170, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00011454563152502163}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 09:27:57,941] Trial 987 finished with value: 0.6789838337182448 and parameters: {'num_layers': 4, 'batch_size': 167, 'layer_size_1': 246, 'layer_size_2': 179, 'layer_size_3': 194, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00011692031797974427}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 09:28:35,329] Trial 984 finished with value: 0.5866050808314087 and parameters: {'num_layers': 4, 'batch_size': 161, 'layer_size_1': 247, 'layer_size_2': 173, 'layer_size_3': 169, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00011504078070009096}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 09:29:16,026] Trial 989 finished with value: 0.6674364896073903 and parameters: {'num_layers': 4, 'batch_size': 166, 'layer_size_1': 246, 'layer_size_2': 134, 'layer_size_3': 172, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00011209543924750548}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 09:43:12,604] Trial 990 finished with value: 0.6997690531177829 and parameters: {'num_layers': 4, 'batch_size': 166, 'layer_size_1': 246, 'layer_size_2': 177, 'layer_size_3': 186, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00011266189632870234}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 09:44:24,482] Trial 991 finished with value: 0.6859122401847575 and parameters: {'num_layers': 4, 'batch_size': 167, 'layer_size_1': 253, 'layer_size_2': 172, 'layer_size_3': 173, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00013165830733380488}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 09:45:53,256] Trial 992 finished with value: 0.7020785219399538 and parameters: {'num_layers': 4, 'batch_size': 168, 'layer_size_1': 253, 'layer_size_2': 169, 'layer_size_3': 185, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00010806842713534807}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 09:47:08,298] Trial 995 finished with value: 0.7020785219399538 and parameters: {'num_layers': 4, 'batch_size': 169, 'layer_size_1': 253, 'layer_size_2': 177, 'layer_size_3': 180, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.0001251486819274457}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 09:47:12,059] Trial 994 finished with value: 0.6859122401847575 and parameters: {'num_layers': 4, 'batch_size': 166, 'layer_size_1': 252, 'layer_size_2': 175, 'layer_size_3': 180, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00012981729119581584}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 09:47:24,189] Trial 997 finished with value: 0.6928406466512702 and parameters: {'num_layers': 4, 'batch_size': 182, 'layer_size_1': 253, 'layer_size_2': 178, 'layer_size_3': 186, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00019461764394276755}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 09:47:37,605] Trial 993 finished with value: 0.6951501154734411 and parameters: {'num_layers': 4, 'batch_size': 167, 'layer_size_1': 252, 'layer_size_2': 179, 'layer_size_3': 188, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00012810066491467976}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 09:47:53,696] Trial 996 finished with value: 0.6836027713625866 and parameters: {'num_layers': 4, 'batch_size': 169, 'layer_size_1': 253, 'layer_size_2': 169, 'layer_size_3': 180, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.0001377064521194708}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 09:48:06,775] Trial 998 finished with value: 0.6558891454965358 and parameters: {'num_layers': 4, 'batch_size': 182, 'layer_size_1': 256, 'layer_size_2': 169, 'layer_size_3': 177, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.0001396905181628659}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 09:49:33,522] Trial 999 finished with value: 0.6974595842956121 and parameters: {'num_layers': 4, 'batch_size': 170, 'layer_size_1': 256, 'layer_size_2': 174, 'layer_size_3': 187, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00019975987169495185}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 10:02:22,107] Trial 1000 finished with value: 0.6928406466512702 and parameters: {'num_layers': 4, 'batch_size': 180, 'layer_size_1': 252, 'layer_size_2': 176, 'layer_size_3': 175, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00019694152761621584}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 10:04:08,677] Trial 1001 finished with value: 0.6882217090069284 and parameters: {'num_layers': 4, 'batch_size': 180, 'layer_size_1': 253, 'layer_size_2': 176, 'layer_size_3': 181, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00018916259698750613}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 10:05:31,067] Trial 1002 finished with value: 0.6951501154734411 and parameters: {'num_layers': 4, 'batch_size': 172, 'layer_size_1': 256, 'layer_size_2': 176, 'layer_size_3': 186, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00013903011017610357}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 10:06:14,870] Trial 1003 finished with value: 0.6374133949191686 and parameters: {'num_layers': 4, 'batch_size': 180, 'layer_size_1': 256, 'layer_size_2': 175, 'layer_size_3': 186, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 9.787775584793423e-05}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 10:06:18,294] Trial 1004 finished with value: 0.628175519630485 and parameters: {'num_layers': 4, 'batch_size': 180, 'layer_size_1': 256, 'layer_size_2': 169, 'layer_size_3': 184, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00010049676474442605}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 10:06:40,657] Trial 1005 finished with value: 0.6327944572748267 and parameters: {'num_layers': 4, 'batch_size': 181, 'layer_size_1': 245, 'layer_size_2': 170, 'layer_size_3': 188, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00010424056835918424}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 10:07:24,721] Trial 1007 finished with value: 0.5935334872979214 and parameters: {'num_layers': 4, 'batch_size': 182, 'layer_size_1': 256, 'layer_size_2': 167, 'layer_size_3': 185, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 8.763149978517675e-05}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 10:07:29,903] Trial 1008 finished with value: 0.6605080831408776 and parameters: {'num_layers': 4, 'batch_size': 172, 'layer_size_1': 245, 'layer_size_2': 175, 'layer_size_3': 189, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 8.688538847215895e-05}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 10:07:58,926] Trial 1006 finished with value: 0.6651270207852193 and parameters: {'num_layers': 4, 'batch_size': 172, 'layer_size_1': 256, 'layer_size_2': 170, 'layer_size_3': 185, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 9.272481815623818e-05}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 10:10:42,262] Trial 1009 finished with value: 0.6027713625866051 and parameters: {'num_layers': 4, 'batch_size': 157, 'layer_size_1': 245, 'layer_size_2': 185, 'layer_size_3': 185, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 8.66860285863062e-05}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 10:21:01,061] Trial 1010 finished with value: 0.6327944572748267 and parameters: {'num_layers': 4, 'batch_size': 158, 'layer_size_1': 245, 'layer_size_2': 184, 'layer_size_3': 184, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 9.882400652956777e-05}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 10:22:08,760] Trial 1011 finished with value: 0.651270207852194 and parameters: {'num_layers': 4, 'batch_size': 173, 'layer_size_1': 245, 'layer_size_2': 185, 'layer_size_3': 185, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 9.177319724638266e-05}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 10:23:20,931] Trial 1012 finished with value: 0.651270207852194 and parameters: {'num_layers': 4, 'batch_size': 173, 'layer_size_1': 246, 'layer_size_2': 180, 'layer_size_3': 192, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 8.980824364820714e-05}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 10:23:38,018] Trial 1013 finished with value: 0.651270207852194 and parameters: {'num_layers': 4, 'batch_size': 173, 'layer_size_1': 245, 'layer_size_2': 186, 'layer_size_3': 180, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 9.173485275704914e-05}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 10:24:14,661] Trial 1015 finished with value: 0.6836027713625866 and parameters: {'num_layers': 4, 'batch_size': 172, 'layer_size_1': 248, 'layer_size_2': 181, 'layer_size_3': 194, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 8.92827398873687e-05}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 10:25:17,733] Trial 1014 finished with value: 0.651270207852194 and parameters: {'num_layers': 4, 'batch_size': 158, 'layer_size_1': 246, 'layer_size_2': 171, 'layer_size_3': 190, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00010121634816229194}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 10:26:38,683] Trial 1017 finished with value: 0.6351039260969977 and parameters: {'num_layers': 4, 'batch_size': 158, 'layer_size_1': 247, 'layer_size_2': 185, 'layer_size_3': 181, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00010272988098497656}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 10:26:51,706] Trial 1016 finished with value: 0.605080831408776 and parameters: {'num_layers': 4, 'batch_size': 158, 'layer_size_1': 245, 'layer_size_2': 184, 'layer_size_3': 194, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 8.69580399997863e-05}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 10:28:08,030] Trial 1018 finished with value: 0.6928406466512702 and parameters: {'num_layers': 4, 'batch_size': 158, 'layer_size_1': 246, 'layer_size_2': 182, 'layer_size_3': 181, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.0001379602793973434}. Best is trial 919 with value: 0.7621247113163973.
# [I 2024-05-23 10:29:34,205] Trial 1019 finished with value: 0.6905311778290993 and parameters: {'num_layers': 4, 'batch_size': 172, 'layer_size_1': 245, 'layer_size_2': 183, 'layer_size_3': 180, 'activation_function': 'tanh', 'optimizer': 'adamax', 'lr': 0.00012987062236587943}. Best is trial 919 with value: 0.7621247113163973.
